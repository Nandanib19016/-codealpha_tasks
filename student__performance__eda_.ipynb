# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandanib19016/-codealpha_tasks/blob/main/student__performance__eda_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
!1s
# Out:
# /bin/bash: line 1: 1s: command not found

# %% [markdown]
# # uploding the file

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c1ea20b-0de4-4eea-aaf2-f130cae7a86b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c1ea20b-0de4-4eea-aaf2-f130cae7a86b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# checking csv file

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'student_performance (1).csv', 'sample_data']

# %% [markdown]
# import the library from python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA LOADING

# %%
import pandas as pd
df = pd.read_csv('student_performance (1).csv')

# %% [markdown]
# Head is used to display the first row of a dataset.

# %% [markdown]
# DATA CLEANING

# %%
display(df.head())

# %%
import pandas as pd
df = pd.read_csv('student_performance (1).csv')
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# student_id               object
# gender                   object
# age                       int64
# study_hours_per_week      int64
# attendance_rate         float64
# parent_education         object
# internet_access          object
# extracurricular          object
# previous_score            int64
# final_score               int64
# passed                   object
# dtype: object

# %% [markdown]
# # missing value analysis

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            500 non-null    object
#  1   gender                500 non-null    object
#  2   age                   500 non-null    int64
#  3   study_hours_per_week  500 non-null    int64
#  4   attendance_rate       500 non-null    float64
#  5   parent_education      383 non-null    object
#  6   internet_access       500 non-null    object
#  7   extracurricular       500 non-null    object
#  8   previous_score        500 non-null    int64
#  9   final_score           500 non-null    int64
#  10  passed                500 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 43.1+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# student_id                0
# gender                    0
# age                       0
# study_hours_per_week      0
# attendance_rate           0
# parent_education        117
# internet_access           0
# extracurricular           0
# previous_score            0
# final_score               0
# passed                    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(117)

# %%
df[df.isnull().any(axis=1)]
# Out:
#     student_id  gender  age  study_hours_per_week  attendance_rate  \
# 7      STU0008  Female   15                    21             81.7
# 9      STU0010  Female   15                     8             95.7
# 10     STU0011  Female   16                    10             57.0
# 12     STU0013  Female   19                     4             69.2
# 15     STU0016    Male   16                    13             88.1
# ..         ...     ...  ...                   ...              ...
# 490    STU0491    Male   19                    21             69.7
# 491    STU0492  Female   16                    15             95.3
# 492    STU0493  Female   16                     5             59.1
# 493    STU0494    Male   17                     5             59.9
# 498    STU0499    Male   17                    29             91.3
#
#     parent_education internet_access extracurricular  previous_score  \
# 7                NaN             Yes             Yes              89
# ...

# %% [markdown]
# correlation analysis

# %%
print(df.corr(numeric_only=True))
# Out:
#                            age  study_hours_per_week  attendance_rate  \
# age                   1.000000             -0.055204         0.026155
# study_hours_per_week -0.055204              1.000000        -0.016038
# attendance_rate       0.026155             -0.016038         1.000000
# previous_score       -0.106613             -0.076127        -0.033069
# final_score          -0.047819              0.803903         0.240697
#
#                       previous_score  final_score
# age                        -0.106613    -0.047819
# study_hours_per_week       -0.076127     0.803903
# attendance_rate            -0.033069     0.240697
# previous_score              1.000000     0.164958
# final_score                 0.164958     1.000000

# %% [markdown]
# VISUALIZATION

# %% [markdown]
# Histogram

# %%
plt.hist(df['final_score'])
plt.title('Distribution of Final Scores')
plt.xlabel('Final Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# scatter plot

# %%
plt.scatter(df['study_hours_per_week'], df['final_score'])
plt.title('Study Hours per Week vs Final Score')
plt.xlabel('Study Hours per Week')
plt.ylabel('Final Score')
plt.show()

# %% [markdown]
# boxplot

# %%
plt.boxplot(df['final_score'])
plt.title('Distribution of Final Scores (Boxplot)')
plt.ylabel('Final Score')
plt.show()

# %%
df.dtypes

# %% [markdown]
# Hypothesis Testing

# %%
df[['study_hours_per_week','final_score']].corr()
# Out:
#                       study_hours_per_week  final_score
# study_hours_per_week              1.000000     0.803903
# final_score                       0.803903     1.000000

# %% [markdown]
# # conclusion

# %% [markdown]
# -higher study hours generally imporve final scores .
# -attendance postivily affects academic performance .
# -few outlines were detected in the datasheet .
